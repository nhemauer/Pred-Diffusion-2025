# %%
### Preprocessing

import pandas as pd
import random
import warnings

warnings.filterwarnings('ignore')

random.seed(1337)

# %%
### Boehmke et al. 2017

# Data
boehmke_2017_full = pd.read_stata(r"data/boehmke2017.dta")

covariates = ["srcs_decay","nbrs_lag","rpcpinc","totpop","legp_squire",
                "citi6010","unif_rep","unif_dem","time","time_sq","time_cube"]
boehmke_2017 = boehmke_2017_full[["state", "year", "policy", "adopt"] + covariates].dropna()

# Define X and y
X = boehmke_2017.drop(columns = ['adopt', 'year', 'policy']).copy()
X = pd.get_dummies(X, columns = ['state'], drop_first = True)  # drop_first avoids perfect multicollinearity
y = boehmke_2017['adopt']

# Check number of unique policies
print(f"Number of Policies: {boehmke_2017['policy'].nunique()}")

# DV Balance
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 86
# Number of 1s in y: 2222.0
# Number of 0s in y: 42235
# Positive Proportion: 0.049980880401286634

# %%
### Boushey 2016

# Data
boushey_2016_full = pd.read_stata(r"data/boushey2016.dta")

# Covariates
covariates = ["policycongruent","gub_election","elect2", "hvd_4yr", "fedcrime",
                "leg_dem_per_2pty","dem_governor","insession","propneighpol",
                "citidist","squire_prof86","citi6008","crimespendpc","crimespendpcsq",
                "violentthousand","pctwhite","stateincpercap","logpop","counter","counter2","counter3"]
boushey_2016 = boushey_2016_full[["state", "billname", "dvadopt"] + covariates].dropna()

# Define X and y
X = boushey_2016[covariates].copy()
y = boushey_2016['dvadopt']

# Check number of unique policies
print(f"Number of Policies: {boushey_2016['billname'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 43
# Number of 1s in y: 1445.0
# Number of 0s in y: 19108
# Positive Proportion: 0.07030603804797353

# %%
### Bricker & Lacombe 2021

bricker_lacombe_2021_full = pd.read_stata(r"data/bricker_lacombe2021.dta")

covariates = ["std_score", "initiative", "init_sigs", "std_population", "std_citideology", 
              "unified", "std_income", "std_legp_squire", "duration", "durationsq", "durationcb"]
bricker_lacombe_2021 = bricker_lacombe_2021_full[["state", "year", "policyno", "adoption"] + covariates].dropna()

y = bricker_lacombe_2021['adoption']

# Check number of unique policies
print(f"Number of Policies: {bricker_lacombe_2021['policyno'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 244
# Number of 1s in y: 4838.0
# Number of 0s in y: 81040
# Positive Proportion: 0.05633573208505089

# %%
### Karch et al. 2016

# Data
karch_2016_full = pd.read_stata(r"data/karch2016.dta")

covariates = ["traditional","nborsstd","prevadoptstd","complexity","igrole",
              "regov","unified","perdemstd","incpcadjstd","exppcadjstd",
              "logpopstd","collegstd","perurbanstd","profstd"]
karch_2016 = karch_2016_full[["adopt", "compnum"] + covariates].dropna()

y = karch_2016['adopt']

# Check number of unique policies
print(f"Number of Policies: {karch_2016['compnum'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 38
# Number of 1s in y: 783.0
# Number of 0s in y: 41686
# Positive Proportion: 0.018436977560102662

# %%
### Kreitzer & Boehmke 2016 

# Data
kreitzer_boehmke_2016_full = pd.read_stata(r"data/kreitzer_boehmke2016.dta")

covariates = [
    "norrander_legality", "religadhrate", "initdif", "dem_gov", "uni_dem_leg",
    "fem_dem", "nbrspct", "rescaledmedincome", "rescaledpopsize", "time", 
    "time2", "webster", "policy_num"
]

kreitzer_boehmke_2016 = kreitzer_boehmke_2016_full[["adopt_policy", "state"] + covariates].dropna()

# Define X and y
X = kreitzer_boehmke_2016.drop(columns = ['adopt_policy', 'state']).copy()
X = pd.get_dummies(X, columns = ['policy_num'], drop_first = True)  # drop_first avoids perfect multicollinearity
y = kreitzer_boehmke_2016['adopt_policy']

# Check number of unique policies
print(f"Number of Policies: {kreitzer_boehmke_2016['policy_num'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 29
# Number of 1s in y: 672.0
# Number of 0s in y: 28991
# Positive Proportion: 0.022654485385834203

# %%
### Parinandi 2020

# Data
parinandi2020_full = pd.read_stata(r"data/parinandi2020.dta")

covariates = [
    "adagovideology", "citizenideology", "medianivoteshare", "partydecline", "squirescore",
    "incunemp", "pctpercapincome", "percenturban", "ugovd", "percentfossilprod", "renergyprice11",
    "deregulated", "geoneighborlag", "ideoneighborlag", "premulation1", "featureyear"
]

parinandi2020 = parinandi2020_full[["state", "year", "featurenumber", 'feature', "oneemulation"] + covariates].dropna()

# Define X and y
X = parinandi2020.drop(columns = ['oneemulation']).copy()
y = parinandi2020['oneemulation']

# Check number of unique policies
print(f"Number of Policies: {parinandi2020['featurenumber'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 236
# Number of 1s in y: 367.0
# Number of 0s in y: 53726
# Positive Proportion: 0.006784611847251654

# %%
### Berry and Berry 1990

# Data
berry_berry1990_full = pd.read_csv("data/berry_berry1990.txt", delim_whitespace = True, header = None)
berry_berry1990_full.columns = ["state", "year", "adopt", "fiscal_1", "party", "elect1", "elect2", "income_1", "neighbor", "nbrpercn", "religion"]

berry_berry1990 = berry_berry1990_full[berry_berry1990_full['party'] != 9].copy()

# Define X and y
X = berry_berry1990.drop(columns = ['adopt', 'neighbor', 'state', 'year']).copy()
y = berry_berry1990['adopt']

# Check number of unique policies
# Berry and Berry 1990 is a single policy study

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of 1s in y: 27
# Number of 0s in y: 829
# Positive Proportion: 0.03154205607476635

# %%
### LaCombe and Boehmke 2021

# Data
lacombe_boehmke2021_full = pd.read_stata(r"data/lacombe_boehmke2021.dta")

covariates = [
    "initiative", "init_sigs", "std_latnt_decay", "std_nbrs_lag", "std_population",
    "std_masssociallib_est", "unified", "duration", "durationsq", "durationcb", "std_income",
    "std_bowen_1", "std_bowen_2", "change_pop", "change_inc", "party_change", "year"
]

lacombe_boehmke2021 = lacombe_boehmke2021_full[["adoption", "policyno", 'state'] + covariates].dropna()

y = lacombe_boehmke2021['adoption']

# Check number of unique policies
print(f"Number of Policies: {lacombe_boehmke2021['policyno'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 534
# Number of 1s in y: 10652.0
# Number of 0s in y: 301347
# Positive Proportion: 0.0341411350677406

# %%
### Mallinson 2019

# Data
mallinson_2019_full = pd.read_csv(r"data/mallinson2019.csv")

covariates = ["neighbor_prop", "ideology_relative_hm", "congress_majortopic", "init_avail", "init_qual", "divided_gov",
              "legprof_squire", "percap_log", "population_log", "mip", "complexity_topic", "mip_complexity_topic", "nyt", "year_count", "time_log"]
mallinson_2019 = mallinson_2019_full[["adopt", "state", "policy"] + covariates].dropna()

# Define X and y
X = mallinson_2019.drop(columns = ['adopt', "state", 'policy']).copy()
y = mallinson_2019['adopt']

# Check number of unique policies
print(f"Number of Policies: {mallinson_2019['policy'].nunique()}")

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of Policies: 556
# Number of 1s in y: 11006
# Number of 0s in y: 288593
# Positive Proportion: 0.03673577014609528

# %%
### Mallinson and Lovell 2022

# Data
mallinson_lovell_2022_full = pd.read_csv(r"data/mallinson_lovell2022.csv")

covariates = ["republican", "legprof_squire", "exp_pupil10000_adj", "mathscore4th", "readscore4th", "time"]
mallinson_lovell_2022 = mallinson_lovell_2022_full[["adopt", "state", "year"] + covariates].dropna()

y = mallinson_lovell_2022['adopt']

# Check number of unique policies
# Berry and Berry 1990 is a single policy study

# Count the number of 1s in y
print(f"Number of 1s in y: {y.sum()}")
print(f"Number of 0s in y: {(y == 0).sum()}")
print(f"Positive Proportion: {y.sum() / len(y)}")

# Time period taken from original paper
# Out:
# Number of 1s in y: 31
# Number of 0s in y: 1208
# Positive Proportion: 0.025020177562550445
